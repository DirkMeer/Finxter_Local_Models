# %%
# Generic code that will work on any system. (See tutorial for more details and alternative version).
from diffusers.pipelines.auto_pipeline import AutoPipelineForText2Image
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
pipe = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo")
pipe.to(device)

# %%
def generate_image(prompt: str):
    image = pipe(prompt=prompt, num_inference_steps=1, guidance_scale=0.0).images[0]
    return image

# %%
generate_image("A beautiful sunset over the ocean.")

# %% [markdown]
# Example output:
#
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %%
generate_image("Jedi Master Yoda eating a slice of pizza in the middle of a forest.")

# %% [markdown]
# Example output:
#
# ![image.png](attachment:image.png)  ![image-18.png](attachment:image-18.png)
